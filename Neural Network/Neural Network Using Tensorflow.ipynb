# %% [markdown]
# # Neural Network Using Tensorflow

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input

from tensorflow.keras import Sequential
from tensorflow.keras.losses import MeanSquaredError

# %%
dataset=pd.read_csv('dataset.csv')

# %%
x_features=['Price','shipping','Marketing','Material']
x=dataset[x_features]
y=dataset[['sold']].values
x_train=np.array(x)
y_train=np.array(y)

# %%
model=Sequential([
    Dense(units=3,activation='sigmoid'),
    Dense(units=1,activation='sigmoid')
]
)

model.compile(loss=MeanSquaredError())
model.fit(x_train,y_train,epochs=100)   #Epochs=Iterations
y_pred = model.predict(x_train)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 742ms/step - loss: 0.1739
# Epoch 2/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1738
# Epoch 3/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1737
# Epoch 4/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1736
# Epoch 5/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1735
# Epoch 6/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1734
# Epoch 7/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1733
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1733
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1732
# Epoch 10/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1732
# Epoch 11/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1731
# Epoch 12/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1731
# ...

# %%
fig,ax=plt.subplots(1,4,figsize=(12,6),sharey=True)
for i in range(len(ax)):
    
    ax[i].scatter(x_train[:,i],y_train,label='Actual data')
    ax[i].set_xlabel(x_features[i])
    ax[i].scatter(x_train[:,i],y_pred,label='Model Prediction',c='r')
ax[0].set_ylabel('Price')
plt.show()

# %%
w1_1, b1_1 = model.layers[0].get_weights()
print(w1_1,b1_1)
# Out:
# [[ 0.72163725  0.2884438  -0.3167172 ]
#  [ 0.43629944 -0.71923065 -0.48438162]
#  [-0.19059122 -0.36490738  0.76628685]
#  [ 0.59854436 -0.22028065 -0.42189527]] [0. 0. 0.]

# %%
w2_2, b2_2 = model.layers[1].get_weights()
print(w2_2,b2_2)
