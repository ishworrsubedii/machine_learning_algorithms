# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Data
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
w = 0
b = 0

# %%
#logistci regression 
def sigmoid(x, w, b):
    m = x.shape[0]  # Get the number of samples in x
    logistic = np.zeros((m,))
    for i in range(m):
        z = w * x[i] + b
        logistic[i] = 1 / (1 + np.exp(-z))
        
    return logistic

logistic_calculation = sigmoid(x_train, w, b)

# %%
logistic_calculation
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5])

# %%
plt.scatter(x_train,y_train,label='Actual Data',c='r')
plt.plot(x_train,logistic_calculation,label='Model Prediction')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %% [markdown]
# This is just an example of a logistic or sigmoid function; the model prediction is not applicable to the real world. If you want to predict correctly, you have to find or calculate the values of w and b using gradient descent.

# %% [markdown]
# ## Decision Boundary

# %% [markdown]
# - Using Single Data

# %%
w=1
b=-3
# db=wx+b
z=3-x_train

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5), sharey=True)


# fig,ax=plt.subplot(1,2,figsize=(8,3))
ax.scatter(x_train[pos],y_train[pos],c='r',marker='X',label='Posative')
ax.scatter(x_train[neg],y_train[neg],c='b',marker='o',label='Negative')
ax.plot(x_train,z,label='Boundary Line')

plt.legend()
plt.show()

# %% [markdown]
# - Using 2d Data

# %%
x1 = np.array([[0.5, 1.5], [1, 1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y1 = np.array([0, 0, 0, 1, 1, 1])
pos = y1 == 1
neg = y1 == 0
b = -3
w1 = 1
w2 = 1

x_boundary = [min(x1[:, 0]), max(x1[:, 0])]
y_boundary = []
for x in x_boundary:
#w1 * x1 + w2 * x2 + b = 0
#w2* x2 = -b - w1 * x1
#x2 = (-b - w1 * x1) / w2
#g_z=w1_x1+w2_x2+b
    y_boundary.append((-1 *(b + w1 * x)) / w2) 

# Plot the data points and decision boundary
plt.scatter(x1[pos,0],x1[pos,1],c='r',marker='X')
plt.scatter(x1[neg,0],x1[neg,1],c='b',marker='o')



plt.plot(x_boundary, y_boundary, c='red', label='Decision Boundary')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()
